# %% [markdown]
# # <center>PrivacyBench: ViT Baseline</center>

# %% [markdown]
# ViT Baseline for PrivacyBench: Exploring Transformer-Based Performance Reference.
#
# As the second step in evaluating privacy-preserving machine learning techniques within the PrivacyBench framework, we implement and assess a Vision Transformer (ViT) baseline. This transformer-based architecture provides an alternative performance benchmark, enabling a broader comparison of privacy techniques in terms of utility, computational efficiency, and robustness across model types.
#
# ---

# %%
# %load_ext watermark 
# %load_ext autoreload 

# %watermark -p torch,datasets,transformers
# %autoreload 2
# Out:
# torch       : 2.6.0
# datasets    : 3.5.0
# transformers: 4.51.1

# %%
import os
import sys 

sys.path.append("../..")

import time
from src.train import train_model
from src.config import AUGMENT, ExperimentName

# %%
## Replace with appropritate values
data_name_ = "skin_lesions" #"alzheimer" #
base_type_ = "vit"
num_labels_ = 8 #Alzheimer-4 & skin_lesions-8 classlabels
experiment_name_ = ExperimentName.VIT_BASE

# %%
start_time = time.perf_counter()

dm, trainer, model = train_model(
    data_name = data_name_, 
    experiment_name = experiment_name_, 
    base_type = base_type_,
    augmentation=AUGMENT,
    num_labels = num_labels_
    )

end_time = time.perf_counter()
duration = end_time - start_time
print(f"\n🕒 Total Time: {duration // 60:.0f} min {duration % 60:.0f} sec")
# Out:
# [codecarbon WARNING @ 00:14:54] Multiple instances of codecarbon are allowed to run at the same time.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/emeka/.netrc
# wandb: Currently logged in as: emyrs to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/emeka/PrivacyBench/logs/wandb/run-20250514_001454-dbe5yy8r</code>
# Syncing run <strong><a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/dbe5yy8r' target="_blank">ViT Baseline_skin_lesions</a></strong> to <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %% [markdown]
# ----
#
# ## Using Saved Best Model For Evaluation On Test Data

# %%
trainer.test(model=model, datamodule=dm, ckpt_path="best")
# Out:
# Restoring states from the checkpoint path at ../../logs/models/vit-model/version_0/checkpoints/epoch=25-step=15106.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from the checkpoint at ../../logs/models/vit-model/version_0/checkpoints/epoch=25-step=15106.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         accuracy          │    0.8774193525314331     │
# │         test_loss         │    0.4878121018409729     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.4878121018409729, 'accuracy': 0.8774193525314331}]
