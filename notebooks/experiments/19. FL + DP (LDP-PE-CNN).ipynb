# %% [markdown]
# ## Federated Learning with Differential Privacy With Opacus (CNN)

# %% [markdown]
# We'll train a federated learning model with local differential privacy using Opacus within the Flower framework. Differential privacy is applied client-side to protect individual data before updates are shared with the server.
#
# --------

# %%
# %load_ext autoreload
# %load_ext watermark
    
# %autoreload 2
# %watermark --python -p torch,flwr,opacus
# Out:
# Python implementation: CPython
# Python version       : 3.12.11
# IPython version      : 9.1.0
#
# torch : 2.6.0
# flwr  : 1.18.0
# opacus: 1.5.3

# %% [markdown]
# --------
#
# ## Loading Dependencies

# %%
import os
import sys
sys.path.append("../../")

import ray
import time

import torch
import torch.nn as nn
from torchvision.models import resnet18, ResNet18_Weights

import logging
from logging import ERROR

from opacus.validators import ModuleValidator

from flwr.common import ndarrays_to_parameters, Context 
from flwr.client import Client, ClientApp
from flwr.server import ServerApp, ServerConfig, ServerAppComponents
from flwr.server.strategy import FedAvg
from flwr.simulation import run_simulation

from src.config import NUM_CLASSES, ExperimentName
from src.paths import RAY_LOG_DIR
from src.FL_client import MedicalImageClient

from src.FL_server import weighted_average, build_evaluate_fn
from src.local_utility import load_yaml_config, set_device, prepare_FL_dataset, get_weights
from src.privacy_engine import make_fully_opacus_safe_resnet18
from src.tracker import reset_base_memory_csv

# %%
# Replace with appropritate values

data_name_ = "skin_lesions" #"alzheimer" #
base_type_ = "cnn"
num_labels_ = 8 #Alzheimer-4 & skin_lesions-8 classlabels
exp_name_ = "LDP-PE"
experiment_name_ = ExperimentName.FL_LDP_PE_CNN

# %%
DEVICE = set_device()
reset_base_memory_csv() 

fed_config = load_yaml_config(key="experiments", item_name=ExperimentName.FL_LDP_PE_CNN)
client_dataloaders = prepare_FL_dataset(exp_name = exp_name_, base_type= base_type_, data_name=data_name_, augment_data=True)

# Opacus logger seems to change the flwr logger to DEBUG level. Set back to INFO
logging.getLogger("flwr").setLevel(logging.INFO)

# %%
def client_fn(context: Context) -> Client:
    """
    Creates and initializes a federated learning client.

    This function initializes a client in the federated learning setup by 
    assigning a unique partitioned dataset and a machine learning model 
    for training and validation.

    Args:
        context (Context): The execution context containing client-specific configurations.

    Returns:
        Client: A configured federated learning client ready to participate in training.
    """
    partition_id = int(context.node_config["partition-id"]) #<--- Get the client partition ID
    
    model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(in_features=model.fc.in_features, out_features=num_labels_)
    #model = make_fully_opacus_safe_resnet18(num_labels_)
    

    # Assign partitioned client dataset
    train_loader, val_loader, test_loader = client_dataloaders[partition_id]
    
    return MedicalImageClient(
        model, 
        train_loader, 
        val_loader,
        exp_name = exp_name_,
        data_name = data_name_,
        base_type = base_type_, 
        client_id=partition_id,
        use_privacy_engine = True,
        target_delta = fed_config['dp_params'].get('target_delta'),
        noise_multiplier = fed_config['dp_params'].get('epsilon')[0],
        max_grad_norm = fed_config['dp_params'].get('max_grad_norm')
        ).to_client()

client = ClientApp(client_fn)

# %%
def server_fn(context: Context):
    """
    Creates and configures the federated learning server using the FedAvg strategy.

    This function initializes the federated learning server with a FedAvg strategy,
    specifying the parameters for client participation in training and evaluation,
    the global model evaluation function, and the metric aggregation function.

    Args:
        context (Context): The execution context for the federated learning server.

    Returns:
        ServerAppComponents: A configured server application with the defined strategy
        and server settings.
    """
    
    #model = make_fully_opacus_safe_resnet18(num_labels_)
    model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
    model.fc = nn.Linear(in_features=model.fc.in_features, out_features=num_labels_)
    params = ndarrays_to_parameters(get_weights(model))
    
    # Create FedAvg strategy
    strategy = FedAvg(
        fraction_fit=1.0,                 #<--- Sample 100% of available clients for training
        fraction_evaluate=1.0,            #<--- Sample 100% of available clients for evaluation
        initial_parameters=params,        #<--- Initial model parameters
        evaluate_fn=build_evaluate_fn(    #<--- Global evaluation function
            exp_name = exp_name_, 
            base_type = base_type_,
            data_name=data_name_, 
            experiment_item=experiment_name_, 
            num_labels=num_labels_
            ),         
        evaluate_metrics_aggregation_fn=weighted_average,  #<-- pass the metric aggregation function
    )
    
    
    # Configure the server with the specified number of federated rounds
    sever_config = ServerConfig(num_rounds=fed_config['num_rounds'])
    
    return ServerAppComponents(strategy = strategy, config = sever_config)

# Wrap the server function in a ServerApp, and instantiate it
server = ServerApp(server_fn = server_fn)

# %%
backend_setup = {
    "init_args": {
        "logging_level": ERROR, 
        "log_to_driver": fed_config.get("log_to_driver")
    },
    "client_resources": {
        "num_cpus": fed_config.get("num_cpus"), 
        "num_gpus": fed_config.get("num_gpus")            
    },
}

# When running on GPU, assign an entire GPU for each client
if DEVICE == "cuda": 
    backend_setup["client_resources"] = {"num_cpus": 1, "num_gpus": 1.0}

# %% [markdown]
# ---
#
# ## Initiate the Simulation
#
# Initiate the simulation by passing the server and client apps, and specify the number of supernodes that will be selected on every round.

# %%
project_root =  os.path.abspath("../../")

ray.shutdown()

ray.init(
    _temp_dir=str(RAY_LOG_DIR),
    runtime_env={
        "env_vars": {
            "PYTHONWARNINGS": "ignore::DeprecationWarning",  # More specific warning filter
            "OMP_NUM_THREADS": "1"  # Prevents thread oversubscription
        },
        "working_dir": project_root,
        'excludes': ['data', '.cache', '.docker', '.local', 'logs/model', 'logs/ray']
    },
    ignore_reinit_error=True
)

start_time = time.perf_counter()

run_simulation(
    server_app = server,
    client_app = client,
    num_supernodes = fed_config.get("num_clients"),
    backend_config=backend_setup
)


end_time = time.perf_counter()
duration = end_time - start_time
print(f"\n🕒 Total Time: {duration // 60:.0f} min {duration % 60:.0f} sec")

ray.shutdown()
# Out:
# 2025-07-23 09:28:32,172	INFO worker.py:1771 -- Started a local Ray instance.
# 2025-07-23 09:28:32,387	INFO packaging.py:530 -- Creating a file package for local directory '/home/emeka/PrivacyBench'.
# 2025-07-23 09:28:32,472	INFO packaging.py:358 -- Pushing file package 'gcs://_ray_pkg_3620b3645621acad.zip' (13.72MiB) to Ray cluster...
# 2025-07-23 09:28:32,511	INFO packaging.py:371 -- Successfully pushed file package 'gcs://_ray_pkg_3620b3645621acad.zip'.
# INFO :      Starting Flower ServerApp, config: num_rounds=5, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# [codecarbon WARNING @ 09:28:33] Multiple instances of codecarbon are allowed to run at the same time.
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/emeka/PrivacyBench/notebooks/experiments/../../src/tracker.py:88: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
# INFO :      initial parameters (loss, other metrics): 2.5526501544534344, {'accuracy': 0.031612903225806455}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
# (ClientAppActor pid=7313)   check_for_updates()
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) [codecarbon WARNING @ 09:28:49] Multiple instances of codecarbon are allowed to run at the same time.
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 4 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_fit: received 3 results and 0 failures
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# WARNING :   No fit_metrics_aggregation_fn provided
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# INFO :      fit progress: (1, 2.5526436730606914, {'accuracy': 0.031612903225806455}, 744.852579553)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_fit: received 3 results and 0 failures
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# INFO :      fit progress: (2, 2.552644772072361, {'accuracy': 0.031612903225806455}, 1483.104376957)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_fit: received 3 results and 0 failures
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# INFO :      fit progress: (3, 2.552644772072361, {'accuracy': 0.031612903225806455}, 2221.3889618390003)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_fit: received 3 results and 0 failures
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 4 minutes 2 seconds
# (ClientAppActor pid=7313) Epsilon value for delta=1e-05 is 10.56
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# INFO :      fit progress: (4, 2.552644772072361, {'accuracy': 0.031612903225806455}, 2960.404138057)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) 07/23/2025 10:18:53:ERROR:Training failed with error: CUDA out of memory. Tried to allocate 424.00 MiB. GPU 0 has a total capacity of 21.95 GiB of which 187.00 MiB is free. Process 7307 has 0 bytes memory in use. Including non-PyTorch memory, this process has 21.26 GiB memory in use. Of the allocated memory 18.53 GiB is allocated by PyTorch, and 2.49 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (ClientAppActor pid=7313) Traceback (most recent call last):
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/logs/ray/session_2025-07-23_09-28-28_900305_5841/runtime_resources/working_dir_files/_ray_pkg_3620b3645621acad/src/privacy_engine.py", line 288, in train_FL_model
# (ClientAppActor pid=7313)     loss.backward()
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# (ClientAppActor pid=7313)     torch.autograd.backward(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# (ClientAppActor pid=7313)     _engine_run_backward(
# ...
# (ClientAppActor pid=7313) 07/23/2025 10:18:55:ERROR:Training failed with error: CUDA out of memory. Tried to allocate 306.00 MiB. GPU 0 has a total capacity of 21.95 GiB of which 179.00 MiB is free. Process 7307 has 0 bytes memory in use. Including non-PyTorch memory, this process has 21.27 GiB memory in use. Of the allocated memory 19.58 GiB is allocated by PyTorch, and 1.45 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (ClientAppActor pid=7313) Traceback (most recent call last):
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/logs/ray/session_2025-07-23_09-28-28_900305_5841/runtime_resources/working_dir_files/_ray_pkg_3620b3645621acad/src/privacy_engine.py", line 288, in train_FL_model
# (ClientAppActor pid=7313)     loss.backward()
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# (ClientAppActor pid=7313)     torch.autograd.backward(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# (ClientAppActor pid=7313)     _engine_run_backward(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# (ClientAppActor pid=7313)     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# (ClientAppActor pid=7313)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 98, in __call__
# (ClientAppActor pid=7313)     return self.hook(module, *args, **kwargs)
# (ClientAppActor pid=7313)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/opacus/grad_sample/grad_sample_module.py", line 340, in capture_backprops_hook
# (ClientAppActor pid=7313)     create_or_accumulate_grad_sample(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/opacus/grad_sample/grad_sample_module.py", line 58, in create_or_accumulate_grad_sample
# (ClientAppActor pid=7313)     param._current_grad_sample = torch.zeros(
# (ClientAppActor pid=7313)                                  ^^^^^^^^^^^^
# (ClientAppActor pid=7313) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 306.00 MiB. GPU 0 has a total capacity of 21.95 GiB of which 179.00 MiB is free. Process 7307 has 0 bytes memory in use. Including non-PyTorch memory, this process has 21.27 GiB memory in use. Of the allocated memory 19.58 GiB is allocated by PyTorch, and 1.45 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 0 minutes 1 seconds
# (ClientAppActor pid=7313) Epsilon value not available.
# (ClientAppActor pid=7313) Seed set to 42
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# (ClientAppActor pid=7313) /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
# (ClientAppActor pid=7313)   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# (ClientAppActor pid=7313) 07/23/2025 10:18:57:ERROR:Training failed with error: CUDA out of memory. Tried to allocate 306.00 MiB. GPU 0 has a total capacity of 21.95 GiB of which 179.00 MiB is free. Process 7307 has 0 bytes memory in use. Including non-PyTorch memory, this process has 21.27 GiB memory in use. Of the allocated memory 19.58 GiB is allocated by PyTorch, and 1.45 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# (ClientAppActor pid=7313) Traceback (most recent call last):
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/logs/ray/session_2025-07-23_09-28-28_900305_5841/runtime_resources/working_dir_files/_ray_pkg_3620b3645621acad/src/privacy_engine.py", line 288, in train_FL_model
# (ClientAppActor pid=7313)     loss.backward()
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# (ClientAppActor pid=7313)     torch.autograd.backward(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# (ClientAppActor pid=7313)     _engine_run_backward(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# (ClientAppActor pid=7313)     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# (ClientAppActor pid=7313)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py", line 98, in __call__
# (ClientAppActor pid=7313)     return self.hook(module, *args, **kwargs)
# (ClientAppActor pid=7313)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/opacus/grad_sample/grad_sample_module.py", line 340, in capture_backprops_hook
# (ClientAppActor pid=7313)     create_or_accumulate_grad_sample(
# (ClientAppActor pid=7313)   File "/home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/opacus/grad_sample/grad_sample_module.py", line 58, in create_or_accumulate_grad_sample
# (ClientAppActor pid=7313)     param._current_grad_sample = torch.zeros(
# (ClientAppActor pid=7313)                                  ^^^^^^^^^^^^
# (ClientAppActor pid=7313) torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 306.00 MiB. GPU 0 has a total capacity of 21.95 GiB of which 179.00 MiB is free. Process 7307 has 0 bytes memory in use. Including non-PyTorch memory, this process has 21.27 GiB memory in use. Of the allocated memory 19.58 GiB is allocated by PyTorch, and 1.45 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# INFO :      aggregate_fit: received 3 results and 0 failures
# (ClientAppActor pid=7313)
# (ClientAppActor pid=7313) 🔎 Tracker: FL + LDP-PE (CNN)
# (ClientAppActor pid=7313) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/skin_lesions/FL_LDP-PE_CNN/client_emissions.csv
# (ClientAppActor pid=7313) ⏱️ Total training time: 0 minutes 1 seconds
# (ClientAppActor pid=7313) Epsilon value not available.
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# wandb: Currently logged in as: emyrs to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/wandb/analytics/sentry.py:259: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}  # noqa
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/wandb/analytics/sentry.py:259: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}  # noqa
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/emeka/PrivacyBench/logs/wandb/run-20250723_101905-55kiwl63</code>
# Syncing run <strong><a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/55kiwl63' target="_blank">FL_LDP-PE_CNN_skin_lesions</a></strong> to <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench</a>
#  View run at <a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/55kiwl63' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench/runs/55kiwl63</a>
# /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=5841) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
#  ___________________________________________________________________________________________________
# ExperimentName.FL_LDP_PE_CNN Model Final Evaluation
#
# Test Accuracy: 3.16% | Precision: 0.12 | Recall: 0.03 | F1-Score: 0.02 | ROC-AUC: 0.49 | MCC: 0.01
#  ___________________________________________________________________________________________________
# ExperimentName.FL_LDP_PE_CNN--skin_lesions Model Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       853
#            1       0.12      0.00      0.00      2242
#            2       0.33      0.00      0.01       674
#            3       0.02      0.04      0.03       155
#            4       0.14      0.17      0.15       476
#            5       0.01      0.35      0.03        55
#            6       0.01      0.69      0.03        52
#            7       0.00      0.00      0.00       143
#
#     accuracy                           0.03      4650
#    macro avg       0.08      0.16      0.03      4650
# weighted avg       0.12      0.03      0.02      4650
#
# ___________________________________________________________________________________________________
#
# 📊 Consolidated Metrics:
# ⏱️ Total Duration: 2986.19 sec
# ✅ Total Energy: 0.11240 kWh
# 🌍 Total CO₂ Emitted: 0.04833 kg
# 🧠 Peak CPU RAM: 0.0474 GB
# 🖥️ Peak GPU VRAM: 20.0319 GB
#
#  ___________________________________________________________________________________________________
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>F1-Score</td><td>▁</td></tr><tr><td>MCC</td><td>▁</td></tr><tr><td>Peak FL CPU RAM (GB)</td><td>▁</td></tr><tr><td>Peak FL GPU VRAM (GB)</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>ROC-AUC</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Total FL CO2 Emitted (kg)</td><td>▁</td></tr><tr><td>Total FL Duration (sec)</td><td>▁</td></tr><tr><td>Total FL Energy (kWh)</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.03</td></tr><tr><td>Experiment Name</td><td>FL_LDP-PE_CNN</td></tr><tr><td>F1-Score</td><td>0.02</td></tr><tr><td>MCC</td><td>0.01</td></tr><tr><td>Model</td><td>FL + LDP-PE (CNN)</td></tr><tr><td>Peak FL CPU RAM (GB)</td><td>0.04735</td></tr><tr><td>Peak FL GPU VRAM (GB)</td><td>20.03186</td></tr><tr><td>Precision</td><td>0.12</td></tr><tr><td>ROC-AUC</td><td>0.49</td></tr><tr><td>Recall</td><td>0.03</td></tr><tr><td>Total FL CO2 Emitted (kg)</td><td>0.04833</td></tr><tr><td>Total FL Duration (sec)</td><td>2986.18545</td></tr><tr><td>Total FL Energy (kWh)</td><td>0.1124</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">FL_LDP-PE_CNN_skin_lesions</strong> at: <a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/55kiwl63' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench/runs/55kiwl63</a><br> View project at: <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/home/emeka/PrivacyBench/logs/wandb/run-20250723_101905-55kiwl63/logs</code>
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# INFO :      fit progress: (5, 2.552644772072361, {'accuracy': 0.031612903225806455}, 3031.655096635)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=7313) /home/emeka/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=7313) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=7313)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 5 round(s) in 3035.27s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 2.702856163183848
# INFO :      		round 2: 2.7028604398171105
# INFO :      		round 3: 2.7028604398171105
# INFO :      		round 4: 2.7028604398171105
# INFO :      		round 5: 2.7028604398171105
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 2.5526501544534344
# INFO :      		round 1: 2.5526436730606914
# INFO :      		round 2: 2.552644772072361
# INFO :      		round 3: 2.552644772072361
# INFO :      		round 4: 2.552644772072361
# INFO :      		round 5: 2.552644772072361
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.024193548387096774),
# INFO :      	              (2, 0.024193548387096774),
# INFO :      	              (3, 0.024193548387096774),
# INFO :      	              (4, 0.024193548387096774),
# INFO :      	              (5, 0.024193548387096774)]}
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.031612903225806455),
# INFO :      	              (1, 0.031612903225806455),
# INFO :      	              (2, 0.031612903225806455),
# INFO :      	              (3, 0.031612903225806455),
# INFO :      	              (4, 0.031612903225806455),
# INFO :      	              (5, 0.031612903225806455)]}
# INFO :
# 🕒 Total Time: 50 min 46 sec
