# %% [markdown]
# # Differential Privacy With Opacus Privacy Engine (CNN)

# %%
# %load_ext autoreload
# %load_ext watermark

# %autoreload 2
# %watermark --python -p torch,opacus,flwr,lightning,torchmetrics,albumentations,wandb
# Out:
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.1.0
#
# torch         : 2.6.0
# opacus        : 1.5.3
# flwr          : 1.18.0
# lightning     : 2.5.1
# torchmetrics  : 1.7.1
# albumentations: 2.0.7
# wandb         : 0.19.11

# %%
# Import Dependencies 
import time
import sys 
sys.path.append("../..")

import wandb 
from src.config import ExperimentName
from src.privacy_engine import train_model

# %% [markdown]
# ----
#
# ## Model Training

# %%
data_name_ = "alzheimer" #"skin_lesions" #
num_labels_ = 4
base_type_ = "cnn"
experiment_name_ = ExperimentName.DP_CNN

# %%
start_time = time.perf_counter()

dm, trainer, model = train_model(
    data_name=data_name_,
    experiment_name=experiment_name_,
    base_type=base_type_,
    num_labels = num_labels_
)

end_time = time.perf_counter()
duration = end_time - start_time
print(f"\n🕒 Total Time: {duration // 60:.0f} min {duration % 60:.0f} sec")
# Out:
# [codecarbon WARNING @ 14:23:24] Multiple instances of codecarbon are allowed to run at the same time.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/emeka/.netrc
# wandb: Currently logged in as: emyrs to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/wandb/analytics/sentry.py:259: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}  # noqa
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/wandb/analytics/sentry.py:259: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}  # noqa
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/emeka/PrivacyBench/logs/wandb/run-20250518_142324-dnr3quyr</code>
# Syncing run <strong><a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/dnr3quyr' target="_blank">DP (CNN)_alzheimer</a></strong> to <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench</a>
#  View run at <a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/dnr3quyr' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench/runs/dnr3quyr</a>
# INFO: Seed set to 42
# 05/18/2025 14:23:26:INFO:Seed set to 42
# INFO: Seed set to 42
# 05/18/2025 14:23:26:INFO:Seed set to 42
# INFO: GPU available: True (cuda), used: True
# 05/18/2025 14:23:27:INFO:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# 05/18/2025 14:23:27:INFO:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 05/18/2025 14:23:27:INFO:HPU available: False, using: 0 HPUs
# 05/18/2025 14:23:27:WARNING:Ignoring drop_last as it is not compatible with DPDataLoader.
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
#   warnings.warn(
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/lightning/pytorch/loggers/wandb.py:397: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 05/18/2025 14:23:27:INFO:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | GradSampleModule   | 11.2 M | train
# 1 | train_acc | MulticlassAccuracy | 0      | train
# 2 | val_acc   | MulticlassAccuracy | 0      | train
# 3 | test_acc  | MulticlassAccuracy | 0      | train
# 4 | criterion | CrossEntropyLoss   | 0      | train
# ---------------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.714    Total estimated model params size (MB)
# 73        Modules in train mode
# 0         Modules in eval mode
# 05/18/2025 14:23:27:INFO:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | GradSampleModule   | 11.2 M | train
# 1 | train_acc | MulticlassAccuracy | 0      | train
# 2 | val_acc   | MulticlassAccuracy | 0      | train
# 3 | test_acc  | MulticlassAccuracy | 0      | train
# 4 | criterion | CrossEntropyLoss   | 0      | train
# ---------------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.714    Total estimated model params size (MB)
# 73        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the smallest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# INFO: Restoring states from the checkpoint path at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# 05/18/2025 14:31:51:INFO:Restoring states from the checkpoint path at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 05/18/2025 14:31:51:INFO:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO: Loaded model weights from the checkpoint at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# 05/18/2025 14:31:51:INFO:Loaded model weights from the checkpoint at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# Final Privacy Budget (ε): 11535.4320
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         accuracy          │    0.5677083134651184     │
# │         test_loss         │    1.3197845220565796     │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 1.3197845220565796, 'accuracy': 0.5677083134651184}]
# DP (CNN)--alzheimer Model Final Evaluation
# Test Accuracy: 56.77% | Precision: 0.49 | Recall: 0.57 | F1-Score: 0.53 | ROC-AUC: 0.71 | MCC: 0.26
#  ___________________________________________________________________________________________________
# DP (CNN)--alzheimer Model Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       110
#            1       0.00      0.00      0.00         8
#            2       0.69      0.72      0.71       381
#            3       0.44      0.59      0.50       269
#
#     accuracy                           0.57       768
#    macro avg       0.28      0.33      0.30       768
# weighted avg       0.49      0.57      0.53       768
#
# ___________________________________________________________________________________________________
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🔎 Tracker: DP (CNN)
# 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/alzheimer/DP_(CNN)/emissions.csv
# ⏱️ Total training time: 514.01 seconds
#
# 📊 From emissions.csv:
# ⏱️ Total Duration: 514.03 sec
# ✅ Total Energy consumed: 0.02512 kWh
# 🌍 Total CO₂ emitted: 0.01080 kg
# 🧠 Peak CPU RAM: 0.14 GB
# 🖥️ Peak GPU VRAM: 3.61 GB
#
# 🕒 Total Time: 8 min 35 sec
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])

# %% [markdown]
# ----
#
# ## Using Saved Best Model For Evaluation On Test Data

# %%
trainer.test(model=model, datamodule=dm, ckpt_path="best")

wandb.finish()
# Out:
# INFO: Restoring states from the checkpoint path at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# 05/18/2025 14:32:01:INFO:Restoring states from the checkpoint path at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 05/18/2025 14:32:01:INFO:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO: Loaded model weights from the checkpoint at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# 05/18/2025 14:32:01:INFO:Loaded model weights from the checkpoint at ../../logs/models/cnn-model/version_0/checkpoints/epoch=6-step=1120.ckpt
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=56950) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         accuracy          │    0.5677083134651184     │
# │         test_loss         │    1.3197845220565796     │
# └───────────────────────────┴───────────────────────────┘
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>▁</td></tr><tr><td>CO2 Emitted (kg)</td><td>▁</td></tr><tr><td>Energy Consumed (kWh)</td><td>▁</td></tr><tr><td>F1-Score</td><td>▁</td></tr><tr><td>MCC</td><td>▁</td></tr><tr><td>Peak CPU RAM (GB)</td><td>▁</td></tr><tr><td>Peak GPU VRAM (GB)</td><td>▁</td></tr><tr><td>Precision</td><td>▁</td></tr><tr><td>ROC-AUC</td><td>▁</td></tr><tr><td>Recall</td><td>▁</td></tr><tr><td>Total Training Duration (sec)</td><td>▁</td></tr><tr><td>accuracy</td><td>▁▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▄▄▄▄▅▅▅▅▆▆▇▇▇▇██</td></tr><tr><td>test_loss</td><td>▁▁</td></tr><tr><td>train_acc</td><td>▁▁▂▄▇▆▇▇▇██</td></tr><tr><td>train_loss</td><td>▇█▅▁▂▂▁▂▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▂▂▂▂▃▃▄▄▄▄▅▅▆▆▇▇▇▇████</td></tr><tr><td>val_acc</td><td>▁▁▁█▇▇█▇▇▇█</td></tr><tr><td>val_loss</td><td>█▇▂▁▂▃▂▃▃▄▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Accuracy</td><td>0.57</td></tr><tr><td>CO2 Emitted (kg)</td><td>0.0108</td></tr><tr><td>Energy Consumed (kWh)</td><td>0.02512</td></tr><tr><td>Experiment Name</td><td>DP (CNN)</td></tr><tr><td>F1-Score</td><td>0.53</td></tr><tr><td>MCC</td><td>0.26</td></tr><tr><td>Model</td><td>DP (CNN)--alzheimer</td></tr><tr><td>Peak CPU RAM (GB)</td><td>0.136</td></tr><tr><td>Peak GPU VRAM (GB)</td><td>3.60542</td></tr><tr><td>Precision</td><td>0.49</td></tr><tr><td>ROC-AUC</td><td>0.71</td></tr><tr><td>Recall</td><td>0.57</td></tr><tr><td>Total Training Duration (sec)</td><td>514.02741</td></tr><tr><td>accuracy</td><td>0.56771</td></tr><tr><td>epoch</td><td>11</td></tr><tr><td>test_loss</td><td>1.31978</td></tr><tr><td>train_acc</td><td>0.56979</td></tr><tr><td>train_loss</td><td>1.29108</td></tr><tr><td>trainer/global_step</td><td>1760</td></tr><tr><td>val_acc</td><td>0.54883</td></tr><tr><td>val_loss</td><td>1.54804</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">DP (CNN)_alzheimer</strong> at: <a href='https://wandb.ai/MLC-FedML/PrivacyBench/runs/dnr3quyr' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench/runs/dnr3quyr</a><br> View project at: <a href='https://wandb.ai/MLC-FedML/PrivacyBench' target="_blank">https://wandb.ai/MLC-FedML/PrivacyBench</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/home/emeka/PrivacyBench/logs/wandb/run-20250518_142324-dnr3quyr/logs</code>

# %% [markdown]
# -----
