# %% [markdown]
# # Central Differential Privacy (Server-Side Clipping)

# %% [markdown]
# **Central Differential Privacy (DP) with Server-Side Clipping** applies two steps:
#
# 1. **Clip client updates**
# 2. **Add noise to the aggregated model**
#
# This setup ensures consistent clipping across all client updates and reduces the need for clients to compute norms locally. However, it adds extra computational burden to the server.
#
# For this, Flower provides DP wrappers around strategies like FedAvg. In our case, we use:
#
# ## ViT: DifferentialPrivacyServerSideFixedClipping
#
# This strategy applies a constant clipping norm to all client updates throughout training. While simpler to implement, it may be less flexible than adaptive clipping in handling model convergence and gradient variability.
#
# ---

# %%
# %load_ext autoreload
# %load_ext watermark
    
# %autoreload 2
# %watermark --python -p torch,flwr
# Out:
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.1.0
#
# torch: 2.6.0
# flwr : 1.18.0

# %% [markdown]
# --------
#
# ## Loading Dependencies

# %%
import os
import sys
sys.path.append("../..")

import ray
import time

import torch.nn as nn
from transformers import ViTForImageClassification

from logging import ERROR

from flwr.common import ndarrays_to_parameters, Context 
from flwr.client import Client, ClientApp
from flwr.server import ServerApp, ServerConfig, ServerAppComponents
from flwr.server.strategy import DifferentialPrivacyServerSideFixedClipping, FedAvg
from flwr.simulation import run_simulation

from src.config import ExperimentName
from src.paths import RAY_LOG_DIR
from src.FL_client import MedicalImageClient
from src.FL_server import weighted_average, build_evaluate_fn
from src.local_utility import load_yaml_config, set_device, prepare_FL_dataset, get_weights

from src.tracker import reset_base_memory_csv

# %%
# Replace with appropritate values
data_name_ = 'alzheimer' #"skin_lesions"  #
base_type_ = "ViT"           
exp_name_ = "CDP-SF"
num_labels_ = 4
experiment_name_ = ExperimentName.FL_CDP_SF_VIT

# %%
DEVICE = set_device()
reset_base_memory_csv() 

fed_config = load_yaml_config(key="experiments", item_name=ExperimentName.FL_CDP_SF_VIT)
client_dataloaders = prepare_FL_dataset(exp_name= exp_name_, data_name=data_name_, base_type=base_type_, augment_data=True)

# %%
def client_fn(context: Context) -> Client:
    """
    Creates and initializes a federated learning client.

    This function initializes a client in the federated learning setup by 
    assigning a unique partitioned dataset and a machine learning model 
    for training and validation.

    Args:
        context (Context): The execution context containing client-specific configurations.

    Returns:
        Client: A configured federated learning client ready to participate in training.
    """
    partition_id = int(context.node_config["partition-id"]) #<--- Get the client partition ID
    
    model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", 
                                                      num_labels=num_labels_, 
                                                      ignore_mismatched_sizes=True
                                                      )

    # Assign partitioned client dataset
    train_loader, val_loader, test_loader = client_dataloaders[partition_id]
    
    return MedicalImageClient(model, train_loader, val_loader, exp_name=exp_name_, data_name = data_name_, base_type=base_type_, client_id=partition_id).to_client()

client = ClientApp(client_fn)

# %%
def server_fn(context: Context):
    """
    Creates and configures the federated learning server using the FedAvg strategy.

    This function initializes the federated learning server with a FedAvg strategy,
    specifying the parameters for client participation in training and evaluation,
    the global model evaluation function, and the metric aggregation function.

    Args:
        context (Context): The execution context for the federated learning server.

    Returns:
        ServerAppComponents: A configured server application with the defined strategy
        and server settings.
    """
    model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", 
                                                      num_labels=num_labels_, 
                                                      ignore_mismatched_sizes=True
                                                      )
    
    params = ndarrays_to_parameters(get_weights(model))
    
    # Create FedAvg strategy
    strategy = FedAvg(
        fraction_fit=1.0,                 #<--- Sample 100% of available clients for training
        fraction_evaluate=1.0,            #<--- Sample 100% of available clients for evaluation
        initial_parameters=params,        #<--- Initial model parameters
        evaluate_fn=build_evaluate_fn(    #<--- Global evaluation function
            exp_name = exp_name_, 
            base_type = base_type_,
            data_name=data_name_, 
            experiment_item=experiment_name_, 
            num_labels=num_labels_
            ),
        evaluate_metrics_aggregation_fn=weighted_average,  #<-- pass the metric aggregation function
    )
    
    # Wrap the strategy with the DifferentialPrivacyServerSideFixedClipping wrapper
    dp_strategy = DifferentialPrivacyServerSideFixedClipping(
        strategy= strategy,
        noise_multiplier= 0.1, #0.001,
        num_sampled_clients=fed_config.get("num_clients"),
        clipping_norm=8.0 #1e-4
        )
    
    # Configure the server with the specified number of federated rounds
    sever_config = ServerConfig(num_rounds=fed_config['num_rounds']) #<--- no. of federated rounds
    
    return ServerAppComponents(strategy = dp_strategy, config = sever_config)

# Wrap the server function in a ServerApp, and instantiate it
server = ServerApp(server_fn = server_fn)

# %%
backend_setup = {
    "init_args": {
        "logging_level": ERROR, 
        "log_to_driver": fed_config.get("log_to_driver")
    },
    "client_resources": {
        "num_cpus": fed_config.get("num_cpus"), 
        "num_gpus": fed_config.get("num_gpus")            
    },
}

# When running on GPU, assign an entire GPU for each client
if DEVICE == "cuda": 
    backend_setup["client_resources"] = {"num_cpus": 1, "num_gpus": 1.0}

# %% [markdown]
# ---
#
# ## Initiate the Simulation
#
# Initiate the simulation by passing the server and client apps, and specify the number of supernodes that will be selected on every round.

# %%
project_root =  os.path.abspath("../..")

ray.shutdown()

ray.init(
    _temp_dir=str(RAY_LOG_DIR),
    runtime_env={
        "env_vars": {
            "PYTHONWARNINGS": "ignore::DeprecationWarning",  # More specific warning filter
            "OMP_NUM_THREADS": "1"  # Prevents thread oversubscription
        },
        "working_dir": project_root,
        'excludes': ['data', '.cache', '.docker', '.local', 'logs/model']
    },
    ignore_reinit_error=True
)

start_time = time.perf_counter()

run_simulation(
    server_app = server,
    client_app = client,
    num_supernodes = fed_config.get("num_clients"),
    backend_config=backend_setup
)


end_time = time.perf_counter()
duration = end_time - start_time
print(f"\n🕒 Total Time: {duration // 60:.0f} min {duration % 60:.0f} sec")

ray.shutdown()
# Out:
# 2025-05-06 18:23:03,091	INFO worker.py:1771 -- Started a local Ray instance.
# 2025-05-06 18:23:03,530	INFO packaging.py:530 -- Creating a file package for local directory '/home/emeka/PrivacyBench'.
# 2025-05-06 18:23:04,078	INFO packaging.py:358 -- Pushing file package 'gcs://_ray_pkg_3ff7e252ceb5a7f9.zip' (17.76MiB) to Ray cluster...
# 2025-05-06 18:23:04,133	INFO packaging.py:371 -- Successfully pushed file package 'gcs://_ray_pkg_3ff7e252ceb5a7f9.zip'.
# 2025-05-06 18:23:05,323 - DEBUG - Asyncio event loop already running.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO :      Starting Flower ServerApp, config: num_rounds=5, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# [codecarbon WARNING @ 18:23:06] Multiple instances of codecarbon are allowed to run at the same time.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=143689) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# (raylet) [2025-05-06 18:23:12,990 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687718400; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:23:22,997 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687706112; capacity: 52589998080. Object creation will fail if spilling is required.
# /home/emeka/PrivacyBench/notebooks/../src/tracker.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
# INFO :      initial parameters (loss, other metrics): 1.3897009372711182, {'accuracy': 0.05078125}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (raylet) [2025-05-06 18:23:33,008 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687558656; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) Seed set to 42
# (ClientAppActor pid=145957) [codecarbon WARNING @ 18:23:33] Multiple instances of codecarbon are allowed to run at the same time.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (ClientAppActor pid=145958) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145958) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (raylet) [2025-05-06 18:23:43,017 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687505408; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) Seed set to 42
# (ClientAppActor pid=145958) [codecarbon WARNING @ 18:23:33] Multiple instances of codecarbon are allowed to run at the same time.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:23:53,027 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687493120; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:24:03,036 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687452160; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:24:13,045 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687267840; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:24:23,056 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687267840; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:24:33,068 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687259648; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:24:43,078 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687222784; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:24:53,089 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687198208; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:25:03,099 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 687149056; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:25:13,109 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686981120; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:25:23,120 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686956544; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:25:33,130 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686915584; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:25:43,140 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686915584; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:25:53,151 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686891008; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT)
# (ClientAppActor pid=145958) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv
# (ClientAppActor pid=145958) ⏱️ Total training time: 2 minutes 28 seconds
# (raylet) [2025-05-06 18:26:03,161 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686858240; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145958) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145958) Seed set to 42
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (ClientAppActor pid=145957)
# (raylet) [2025-05-06 18:26:13,170 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686559232; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:26:23,178 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686555136; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:26:33,185 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686555136; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:26:43,194 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686555136; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:26:53,202 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686514176; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:27:03,211 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686436352; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:27:13,222 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686243840; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:27:23,235 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686247936; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:27:33,244 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686198784; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:27:43,254 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686030848; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:27:53,264 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 686030848; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:28:03,273 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685948928; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:28:13,281 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685756416; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:28:23,289 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685748224; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:28:33,297 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685740032; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:28:43,307 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685699072; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT) [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=145958) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv [repeated 2x across cluster]
# (ClientAppActor pid=145958) ⏱️ Total training time: 2 minutes 42 seconds [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# WARNING :   No fit_metrics_aggregation_fn provided
# (raylet) [2025-05-06 18:28:53,317 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685703168; capacity: 52589998080. Object creation will fail if spilling is required.
# INFO :      aggregate_fit: central DP noise with 0.2667 stdev added
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=143689) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# (raylet) [2025-05-06 18:29:03,327 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685625344; capacity: 52589998080. Object creation will fail if spilling is required.
# INFO :      fit progress: (1, 5.552995920181274, {'accuracy': 0.35859375}, 346.7010756010004)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:29:13,336 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685330432; capacity: 52589998080. Object creation will fail if spilling is required.
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=145958) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight'] [repeated 3x across cluster]
# (ClientAppActor pid=145958) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference. [repeated 3x across cluster]
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (ClientAppActor pid=145957) Seed set to 42
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:29:23,347 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685305856; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145958) Seed set to 42
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:29:33,357 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685297664; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:29:43,368 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685256704; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:29:53,376 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685252608; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:30:03,386 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 685170688; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:30:13,395 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684961792; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:30:23,404 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684961792; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:30:33,414 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684957696; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:30:43,424 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684892160; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:30:53,434 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684883968; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:31:03,444 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684814336; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:31:13,454 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684593152; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:31:23,462 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684535808; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:31:33,472 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684535808; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:31:43,480 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684531712; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957)
# (ClientAppActor pid=145957) 🔎 Tracker: FL + CDP-SF (ViT)
# (ClientAppActor pid=145957) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv
# (ClientAppActor pid=145957) ⏱️ Total training time: 2 minutes 28 seconds
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145957) Seed set to 42
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:31:53,491 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684519424; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT)
# (ClientAppActor pid=145958) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv
# (ClientAppActor pid=145958) ⏱️ Total training time: 2 minutes 43 seconds
# (raylet) [2025-05-06 18:32:03,500 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684498944; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:32:13,509 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684204032; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:32:23,518 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684204032; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:32:33,528 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684171264; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:32:43,537 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684109824; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:32:53,547 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 684093440; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:33:03,556 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683986944; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:33:13,567 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683819008; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:33:23,578 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683761664; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:33:33,589 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683757568; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:33:43,598 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683708416; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:33:53,608 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683708416; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:34:03,616 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683655168; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:34:13,627 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683429888; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957)
# (ClientAppActor pid=145957) 🔎 Tracker: FL + CDP-SF (ViT)
# (ClientAppActor pid=145957) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv
# (ClientAppActor pid=145957) ⏱️ Total training time: 2 minutes 31 seconds
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# (raylet) [2025-05-06 18:34:23,635 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683393024; capacity: 52589998080. Object creation will fail if spilling is required.
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: central DP noise with 0.2667 stdev added
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=143689) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# (raylet) [2025-05-06 18:34:33,644 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683315200; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:34:43,653 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683307008; capacity: 52589998080. Object creation will fail if spilling is required.
# INFO :      fit progress: (2, 3.8268237113952637, {'accuracy': 0.4953125}, 681.9015354170006)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# (raylet) [2025-05-06 18:34:53,663 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683315200; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight'] [repeated 2x across cluster]
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference. [repeated 2x across cluster]
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (ClientAppActor pid=145957) Seed set to 42
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:35:03,674 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 683216896; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight'] [repeated 2x across cluster]
# (ClientAppActor pid=145958) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference. [repeated 2x across cluster]
# (ClientAppActor pid=145958) Seed set to 42
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:35:13,684 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682950656; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:35:23,694 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682962944; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:35:33,703 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682881024; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:35:43,713 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682876928; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:35:53,721 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682835968; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:36:03,732 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682717184; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:36:13,742 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682496000; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:36:23,753 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682500096; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:36:33,764 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682483712; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:36:43,773 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682418176; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:36:53,783 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682344448; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:37:03,793 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682397696; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:37:13,803 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682123264; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:37:23,812 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682135552; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT)
# (ClientAppActor pid=145958) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv
# (ClientAppActor pid=145958) ⏱️ Total training time: 2 minutes 30 seconds
# (ClientAppActor pid=145957)
# (ClientAppActor pid=145958) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145958) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145958) Seed set to 42
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:37:33,821 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682110976; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:37:43,831 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682115072; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:37:53,840 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682086400; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:38:03,850 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682311680; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:38:13,859 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682147840; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:38:23,870 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682123264; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:38:33,879 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 682057728; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:38:43,889 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681988096; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:38:53,899 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681975808; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:39:03,909 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681934848; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:39:13,919 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681779200; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:39:23,929 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681693184; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:39:33,940 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681701376; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:39:43,951 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681680896; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:39:53,960 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681607168; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:40:03,971 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 681488384; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT) [repeated 2x across cluster]
# ...
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:47:44,421 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 677367808; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# (raylet) [2025-05-06 18:47:54,431 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 677367808; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:48:04,441 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 677220352; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:48:14,450 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676962304; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:48:24,459 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676966400; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:48:34,470 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676896768; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT)
# (ClientAppActor pid=145958) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv
# (ClientAppActor pid=145958) ⏱️ Total training time: 2 minutes 27 seconds
# (ClientAppActor pid=145957)
# (ClientAppActor pid=145958) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145958) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145958) Seed set to 42
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:48:44,479 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676888576; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:48:54,489 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676884480; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:49:04,500 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676806656; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:49:14,510 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676597760; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:49:24,521 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676597760; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:49:34,531 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676519936; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:49:44,541 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676519936; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:49:54,551 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676454400; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:50:04,561 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676397056; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# (raylet) [2025-05-06 18:50:14,573 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676143104; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:50:24,584 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676110336; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:50:34,594 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 676040704; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:50:44,605 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675983360; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:50:54,616 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675975168; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:51:04,625 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675930112; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:51:14,635 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675692544; capacity: 52589998080. Object creation will fail if spilling is required.
# (ClientAppActor pid=145958)
# (ClientAppActor pid=145958) 🔎 Tracker: FL + CDP-SF (ViT) [repeated 2x across cluster]
# (ClientAppActor pid=145958) 📁 Logs saved to: /home/emeka/PrivacyBench/logs/emissions/FL_CDP-SF_ViT/client_emissions.csv [repeated 2x across cluster]
# (ClientAppActor pid=145958) ⏱️ Total training time: 2 minutes 36 seconds [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: parameters are clipped by value: 8.0000.
# INFO :      aggregate_fit: central DP noise with 0.2667 stdev added
# (raylet) [2025-05-06 18:51:24,646 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675643392; capacity: 52589998080. Object creation will fail if spilling is required.
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=143689) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# (raylet) [2025-05-06 18:51:34,656 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675618816; capacity: 52589998080. Object creation will fail if spilling is required.
# (raylet) [2025-05-06 18:51:44,666 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675614720; capacity: 52589998080. Object creation will fail if spilling is required.
#  ___________________________________________________________________________________________________
# ExperimentName.FL_CDP_SF_VIT Model Final Evaluation
#
# Test Accuracy: 25.08% | Precision: 0.40 | Recall: 0.25 | F1-Score: 0.18 | ROC-AUC: 0.50 | MCC: 0.00
# (raylet) [2025-05-06 18:51:54,676 E 144026 144062] (raylet) file_system_monitor.cc:111: /home/emeka/PrivacyBench/logs/ray/session_2025-05-06_18-23-00_958142_143689 is over 95% full, available space: 675565568; capacity: 52589998080. Object creation will fail if spilling is required.
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#  ___________________________________________________________________________________________________
# ExperimentName.FL_CDP_SF_VIT Model Classification Report
#               precision    recall  f1-score   support
#
#            0       0.13      0.47      0.20       172
#            1       0.00      0.00      0.00        15
#            2       0.50      0.00      0.00       634
#            3       0.36      0.52      0.43       459
#
#     accuracy                           0.25      1280
#    macro avg       0.25      0.25      0.16      1280
# weighted avg       0.40      0.25      0.18      1280
#
# ___________________________________________________________________________________________________
#
# 📊 Consolidated Metrics:
# ⏱️ Total Duration: 2372.05 sec
# ✅ Total Energy: 0.10158 kWh
# 🌍 Total CO₂ Emitted: 0.04368 kg
# 🧠 Peak CPU RAM: 0.00 GB
# 🖥️ Peak GPU VRAM: 5.96 GB
#
#  ___________________________________________________________________________________________________
# /home/emeka/PrivacyBench/.venv/lib/python3.12/site-packages/codecarbon/output_methods/file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# INFO :      fit progress: (5, 3.8722374081611632, {'accuracy': 0.24453125}, 1711.1582777210006)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 3)
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (ClientAppActor pid=145958) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145958) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145958)   self.pid = os.fork()
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 5 round(s) in 1718.51s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 5.582995997534858
# INFO :      		round 2: 3.774926477008396
# INFO :      		round 3: 4.450233697891235
# INFO :      		round 4: 6.04598930146959
# INFO :      		round 5: 3.6539371013641357
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 1.3897009372711182
# INFO :      		round 1: 5.552995920181274
# INFO :      		round 2: 3.8268237113952637
# INFO :      		round 3: 4.396646308898926
# INFO :      		round 4: 5.982457089424133
# INFO :      		round 5: 3.8722374081611632
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.35766423357664234),
# INFO :      	              (2, 0.49391727493917276),
# INFO :      	              (3, 0.48905109489051096),
# INFO :      	              (4, 0.35766423357664234),
# INFO :      	              (5, 0.24817518248175183)]}
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.05078125),
# INFO :      	              (1, 0.35859375),
# INFO :      	              (2, 0.4953125),
# INFO :      	              (3, 0.49609375),
# INFO :      	              (4, 0.35859375),
# INFO :      	              (5, 0.24453125)]}
# INFO :
# (ClientAppActor pid=145957) Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight'] [repeated 2x across cluster]
# (ClientAppActor pid=145957) You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference. [repeated 2x across cluster]
# (ClientAppActor pid=145957) /home/emeka/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=145957) is multi-threaded, use of fork() may lead to deadlocks in the child.
# (ClientAppActor pid=145957)   self.pid = os.fork()
# 🕒 Total Time: 28 min 60 sec
